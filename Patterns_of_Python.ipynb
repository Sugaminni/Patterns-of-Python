# %% [markdown]
# <a href="https://colab.research.google.com/github/Sugaminni/Patterns-of-Python/blob/main/Patterns_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Looping through a  list

# %%
numbers = [1, 2, 3, 4]

# Takes each item and stores it in n. Then, prints out the numbers 1 at a time in each space
for n in numbers:
    print(n)

# %% [markdown]
# Accumulation: Used to compute totals, averages, gradients, etc.

# %%
numbers = [1, 2, 3, 4]

total = 0

# Takes all the numbers and adds them (0 + 1 = 1 + 2 = 3 .... = 10)
for n in numbers:
    total += n

print(total)

# %% [markdown]
# Building a list: Creating a list from an existing one

# %%
numbers = [1, 2, 3]

result = []

# Makes a new list of numbers using the existing numbers and multiplying by 2
for n in numbers:
    result.append(n * 2)

print(result)

# %% [markdown]
# Conditional Logic: Used when filtering data

# %%
numbers = [1,2,3,4,5,6]

for n in numbers:
    if n % 2 == 0:
        print(n)

# %% [markdown]
# Exercise: Output 1, 4, 9, 16 from [1, 2, 3 ,4]

# %%
numbers = [1, 2, 3, 4]

for n in numbers:
    print(n * n)

# %% [markdown]
# Exercise to filter and output

# %%
numbers = [1,2,3,4,5,6]

for n in numbers:
    if n % 2 == 0:
        print(n * n)

# %% [markdown]
# Filters, multiplies, and prints the squared list from existing one

# %%
numbers = [1,2,3,4,5,6]

squaredlist = []

for n in numbers:
    if n % 2 == 0:
      squaredlist.append(n*n)

print(squaredlist)

# %% [markdown]
# Index-Based Loop: Takes the position in the list and prints out position : number
#
# i = position
#
#
# numbers[i] = value

# %%
numbers = [10, 20, 30]

for i in range(len(numbers)):
    print(i, numbers[i])

# %% [markdown]
# Zip: Parallel Iteration
#
# Basically manual vector multiplcation. In ML; becomes dot product

# %%
x = [1,2,3]
w = [0.2,0.5,0.3]

# Multiply together
for xi, wi in zip(x, w):
    print (xi * wi)

# %% [markdown]
# Dictionary Lookup: Dictionaries store key -> value pairs

# %%
student = {
    "name" : "Alex",
    "age" : 24,
    "major" : "CS"
}

print(student["name"])

# %% [markdown]
# Function Defintion

# %%
# Takes a number and squares it
def square(x):
    return x * x

print(square(5))

# Example ML Function
# def sigmoid(x):
    # return 1/(1+math.exp(-x))

# %% [markdown]
# Exercise: Zips the lists and multiplies them, then prints the accumulated product.

# %%
x = [1,2,3]
w = [0.5,0.2,0.1]

total = 0

for xi, wi in zip(x, w):
    total += xi * wi

print(total)

# %% [markdown]
# Enumerate: Gives index and value at the same time
#
# Useful for:
#
# - Dataset Processing
#
# - Feature Indexing
#
# - Model Weights

# %%
numbers = [10, 20, 30]

# Finds position of the value and prints both
for i, n in enumerate(numbers):
    print(i, n)
# Out:
# 0 10
# 1 20
# 2 30

# %% [markdown]
# Function with Loop

# %%
def sum_list(numbers):
  total = 0

# Loops through the numbers and adds them together
  for n in numbers:
    total += n

  return total

# Prints the total sum of all the numbers added
nums = [1, 2, 3, 4]
print(sum_list(nums))

# %% [markdown]
# Importing Modules: Python Libraries

# %%
import math
# Future Imports for ML: import numpy as np
print(math.sqrt(16))
# Out:
# 4.0
